# %% [markdown]
# <a href="https://colab.research.google.com/github/Atulyadav0008/shuruaat/blob/main/TranscribeSectionE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Section E is the best")
# Out:
# Section E is the best
